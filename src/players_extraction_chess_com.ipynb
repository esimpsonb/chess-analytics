# %%
import requests
#from selenium import webdriver
#from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime
import os
import time
import re

# %%
output_dir = os.path.join("..", "data")

# %%
url = "https://api.chess.com/pub/player/Hikaru"
headers = {"User-Agent": "Mozilla/5.0"}
r = requests.get(url, headers=headers)

# %%
def get_leaderboard_page(game_type="live", page=1):
    """
    Devuelve la lista de jugadores de una página del leaderboard de Chess.com.
    """
    url = f"https://www.chess.com/callback/leaderboard/{game_type}?gameType={game_type}&page={page}&totalPage=10000"
    headers = {"User-Agent": "Mozilla/5.0"}
    
    r = requests.get(url, headers=headers)
    if r.status_code != 200:
        print(f"Error en página {page}: {r.status_code}")
        return []
    
    data = r.json()
    leaders = data.get("leaders", [])
    
    players = []
    for l in leaders:
        u = l["user"]
        players.append({
            "rank": l.get("rank"),
            "username": u.get("username"),
            "title": u.get("chess_title"),
            "country": u.get("country_name"),
            "rating": l.get("score"),
            "games_played": l.get("totalGameCount"),
            "wins": l.get("totalWinCount"),
            "losses": l.get("totalLossCount"),
            "draws": l.get("totalDrawCount")
        })
    return players

# %%
all_players = []
for page in range(1, 6):  # páginas 1 a 5
    print(f"Procesando página {page}...")
    players = get_leaderboard_page("live", page)
    all_players.extend(players)

df = pd.DataFrame(all_players)
df.head(10)
# Out:
# Procesando página 1...
# Procesando página 2...
# Procesando página 3...
# Procesando página 4...
# Procesando página 5...
#    rank          username title        country  rating  games_played   wins  \
# 0     1            Hikaru    GM  United States    3400         43196  33798
# 1     2     MagnusCarlsen    GM         Norway    3367          5591   4040
# 2     3      Firouzja2003    GM         France    3268         14303   7959
# 3     4         LyonBeast    GM         France    3249          3345   2092
# 4     5         lachesisQ    GM         Russia    3232          7493   4312
# 5     6         gurelediz    GM        Türkiye    3226          5369   2697
# 6     7            DenLaz    GM        Belarus    3225          4593   2761
# 7     8             GMWSO    GM  United States    3201          3937   2267
# 8     9  spicycaterpillar    GM  United States    3200          5905   3580
# 9    10          0gZPanda    IM  United States    3198          5478   2932
#
#    losses  draws
# 0    5291   4107
# 1     867    684
# 2    4568   1776
# 3     746    507
# 4    2169   1012
# 5    2141    531
# 6    1114    718
# 7     958    712
# 8    1710    615
# 9    1994    552

# %%
output_path = os.path.join(output_dir, "chess_ratings.csv")
df.to_csv(output_path, index=False, encoding="utf-8")

# %%
ECO_DICT = pd.read_csv("../data/eco_dict.csv").set_index("eco")["name"].to_dict()

# %%
def get_month_games(username, year=datetime.today().year, month=datetime.today().month):
    """
    Descarga y limpia todas las partidas de un mes específico para un jugador.
    - Si no se especifica year y month, usa el mes actual.
    """
    url = f"https://api.chess.com/pub/player/{username.lower()}/games/{year}/{month:02d}"
    headers = {"User-Agent": "Mozilla/5.0"}
    
    r = requests.get(url, headers=headers)
    if r.status_code != 200:
        return pd.DataFrame()
    
    games = r.json().get("games", [])
    
    clean = []
    for g in games:
        pgn = g.get("pgn", "")
        
        # extraer código ECO desde el PGN
        match_code = re.search(r'\[ECO "([A-E]\d{2})"\]', pgn)
        eco_code = match_code.group(1) if match_code else None
        eco_name = ECO_DICT.get(eco_code, None)  # buscar nombre desde dict
        
        clean.append({
            "url": g.get("url"),
            "pgn": pgn,
            "time_control": g.get("time_control"),
            "time_class": g.get("time_class"),
            "accuracies_white": g.get("accuracies", {}).get("white"),
            "accuracies_black": g.get("accuracies", {}).get("black"),
            "white_username": g["white"]["username"],
            "white_rating": g["white"]["rating"],
            "white_result": g["white"]["result"],
            "black_username": g["black"]["username"],
            "black_rating": g["black"]["rating"],
            "black_result": g["black"]["result"],
            "eco": eco_code,
            "eco_name": eco_name,   
            "rules": g.get("rules"),
        })
    
    return pd.DataFrame(clean)

# %%
def get_last_3_months_games(usernames):
    """
    Devuelve un DataFrame con las partidas de los últimos 3 meses
    para todos los jugadores en la lista `usernames`.
    """
    all_games = []
    
    # Año y mes actual
    today = datetime.today()
    year, month = today.year, today.month
    
    # Calcular últimos 3 meses (corrigiendo cambio de año)
    months = [(year, month - i) for i in range(3)]
    months = [(y if m > 0 else y-1, (m-1)%12+1) for (y,m) in months]

    i = 1
    for user in usernames:
        print(f"Descargando partidas de {user}...")
        print(i)
        for y, m in months:
            df_games = get_month_games(user, y, m)  # usamos tu función limpia
            if not df_games.empty:
                all_games.append(df_games)
        time.sleep(1)  # para no saturar la API
        i +=1

    if all_games:
        return pd.concat(all_games, ignore_index=True)
    else:
        return pd.DataFrame()

# %%
def map_result(color, result):
    if result == "win":
        return 1 if color == "white" else 0
    elif result in {"resigned", "checkmated", "timeout", "abandoned"}:
        return 0 if color == "white" else 1
    elif result in {"repetition", "insufficient", "agreed", "timevsinsufficient", "stalemate", "50move"}:
        return 0.5

# %%
usernames = df["username"].tolist()
games_df = get_last_3_months_games(usernames)
# Out:
# Descargando partidas de Hikaru...
# 1
# Descargando partidas de MagnusCarlsen...
# 2
# Descargando partidas de Firouzja2003...
# 3
# Descargando partidas de LyonBeast...
# 4
# Descargando partidas de lachesisQ...
# 5
# Descargando partidas de gurelediz...
# 6
# Descargando partidas de DenLaz...
# 7
# Descargando partidas de GMWSO...
# 8
# Descargando partidas de spicycaterpillar...
# 9
# Descargando partidas de 0gZPanda...
# 10
# Descargando partidas de FairChess_on_YouTube...
# 11
# Descargando partidas de rpragchess...
# 12
# Descargando partidas de NikoTheodorou...
# 13
# Descargando partidas de Philippians46...
# 14
# Descargando partidas de GHANDEEVAM2003...
# 15
# Descargando partidas de FaustinoOro...
# 16
# Descargando partidas de Javokhir_Sindarov05...
# 17
# Descargando partidas de TRadjabov...
# 18
# Descargando partidas de jefferyx...
# 19
# Descargando partidas de artooon...
# 20
# Descargando partidas de Baku_Boulevard...
# 21
# Descargando partidas de Sina-Movahed...
# 22
# Descargando partidas de Parhamov...
# 23
# Descargando partidas de Arseniy_Nesterov...
# 24
# Descargando partidas de AnishGiri...
# 25
# Descargando partidas de vi_pranav...
# 26
# Descargando partidas de RaunakSadhwani2005...
# 27
# Descargando partidas de Bigfish1995...
# 28
# Descargando partidas de wonderfultime...
# 29
# Descargando partidas de VincentKeymer...
# 30
# Descargando partidas de nihalsarin...
# 31
# Descargando partidas de ChessWarrior7197...
# 32
# Descargando partidas de HansOnTwitch...
# 33
# Descargando partidas de PursuitOfHappyness2...
# 34
# Descargando partidas de GM_dmitrij...
# 35
# Descargando partidas de Rud_Makarian...
# 36
# Descargando partidas de Polish_fighter3000...
# 37
# Descargando partidas de MichaelRoiz...
# 38
# Descargando partidas de FabianoCaruana...
# 39
# Descargando partidas de Oleksandr_Bortnyk...
# 40
# Descargando partidas de Andreikka...
# 41
# Descargando partidas de LiamPutnam2008...
# 42
# Descargando partidas de LOVEVAE...
# 43
# Descargando partidas de Chefshouse...
# 44
# Descargando partidas de Grischuk...
# 45
# Descargando partidas de mishanick...
# 46
# Descargando partidas de LPSupi...
# 47
# Descargando partidas de Sanan_Sjugirov...
# 48
# Descargando partidas de legendisback1...
# 49
# Descargando partidas de Indianlad...
# 50
# Descargando partidas de Chef_Zohid...
# 51
# Descargando partidas de ChristopherYoo...
# 52
# Descargando partidas de LevonAronian...
# 53
# Descargando partidas de Brewington_Hardaway...
# 54
# Descargando partidas de Twitch_ElhamBlitz05...
# 55
# Descargando partidas de Grandelicious...
# 56
# Descargando partidas de bancsoo...
# 57
# Descargando partidas de GigaQuparadze...
# 58
# Descargando partidas de Salem-AR...
# 59
# Descargando partidas de Konavets...
# 60
# Descargando partidas de Azerichess...
# 61
# Descargando partidas de Volodar_Murzin...
# 62
# Descargando partidas de Mykola-Bortnyk...
# 63
# Descargando partidas de ChessLover0108...
# 64
# Descargando partidas de sergoy...
# 65
# Descargando partidas de viditchess...
# 66
# Descargando partidas de artin10862...
# 67
# Descargando partidas de Macho_2006...
# 68
# Descargando partidas de Njal28...
# 69
# Descargando partidas de Jospem...
# 70
# Descargando partidas de joppie2...
# 71
# Descargando partidas de GukeshDommaraju...
# 72
# Descargando partidas de KazakhFighter04...
# 73
# Descargando partidas de Fandorine...
# 74
# Descargando partidas de Zhuu96...
# 75
# Descargando partidas de Msb2...
# 76
# Descargando partidas de mitrabhaa...
# 77
# Descargando partidas de xiaotong2008...
# 78
# Descargando partidas de Semyon_Khanin...
# 79
# Descargando partidas de DanielNaroditsky...
# 80
# Descargando partidas de Jumbo...
# 81
# Descargando partidas de LiemLe...
# 82
# Descargando partidas de Shield12...
# 83
# Descargando partidas de Zhalmakhanov_Ramazan...
# 84
# Descargando partidas de Harsha_Bharathakoti...
# 85
# Descargando partidas de DominguezOnYoutube...
# 86
# Descargando partidas de MITerryble...
# 87
# Descargando partidas de moro182...
# 88
# Descargando partidas de Angry_Twin...
# 89
# Descargando partidas de DevikBronstein...
# 90
# Descargando partidas de ChessFighter_2011...
# 91
# Descargando partidas de GMBenjaminBok...
# 92
# Descargando partidas de Turboplombir...
# 93
# Descargando partidas de WIDBIFS...
# 94
# Descargando partidas de Lunaticx...
# 95
# Descargando partidas de Rsnr...
# 96
# Descargando partidas de DanielDardha2005...
# 97
# Descargando partidas de dropstoneDP...
# 98
# Descargando partidas de OparinGrigoriy...
# 99
# Descargando partidas de BogdanDeac...
# 100
# Descargando partidas de Annawel...
# 101
# Descargando partidas de Kacparov...
# 102
# Descargando partidas de Yaacovn...
# 103
# Descargando partidas de Duhless...
# 104
# Descargando partidas de MrTattaglia...
# 105
# Descargando partidas de Denis_Makhnyov...
# 106
# Descargando partidas de Zhigalko_Sergei...
# 107
# Descargando partidas de LastGladiator1...
# 108
# Descargando partidas de Beca95...
# 109
# Descargando partidas de SGchess01...
# 110
# Descargando partidas de Vaathi_Coming...
# 111
# Descargando partidas de frederiksvane...
# 112
# Descargando partidas de amintabatabaei...
# 113
# Descargando partidas de GM_Barcenilla...
# 114
# Descargando partidas de ChessBrah...
# 115
# Descargando partidas de AryanTari...
# 116
# Descargando partidas de GMharikrishna...
# 117
# Descargando partidas de snowlord...
# 118
# Descargando partidas de zvonokchess1996...
# 119
# Descargando partidas de GOGIEFF...
# 120
# Descargando partidas de klimkoj...
# 121
# Descargando partidas de shimastream...
# 122
# Descargando partidas de ricky8632200...
# 123
# Descargando partidas de wudileige...
# 124
# Descargando partidas de michaelq2d5...
# 125
# Descargando partidas de A-Adly...
# 126
# Descargando partidas de GroovyKettle...
# 127
# Descargando partidas de Sargsyan_Shant...
# 128
# Descargando partidas de DonkyDonkyDonkey...
# 129
# Descargando partidas de KuybokarovTemur...
# 130
# Descargando partidas de MrLion3000...
# 131
# Descargando partidas de KNVB...
# 132
# Descargando partidas de Ehsan_GhaemMaghami...
# 133
# Descargando partidas de igorkovalenko...
# 134
# Descargando partidas de rednova1729...
# 135
# Descargando partidas de Cayse...
# 136
# Descargando partidas de GeorgMeier...
# 137
# Descargando partidas de Igor_Janik...
# 138
# Descargando partidas de Bauman_Guy...
# 139
# Descargando partidas de GogiaMetutune...
# 140
# Descargando partidas de Gordima...
# 141
# Descargando partidas de Chopper1905...
# 142
# Descargando partidas de ChessSharkz...
# 143
# Descargando partidas de NeoTerNemo...
# 144
# Descargando partidas de LionTheLeon_06...
# 145
# Descargando partidas de beautifulbird07...
# 146
# Descargando partidas de bardiya_Daneshvar...
# 147
# Descargando partidas de yosephtaher...
# 148
# Descargando partidas de Jakhongir-Vakhidov...
# 149
# Descargando partidas de Zlatan56...
# 150
# Descargando partidas de Dr_Tyger...
# 151
# Descargando partidas de ManuDavid2910...
# 152
# Descargando partidas de iturrizaga...
# 153
# Descargando partidas de vinniethepooh...
# 154
# Descargando partidas de KogotBobra17...
# 155
# Descargando partidas de adotand...
# 156
# Descargando partidas de Antipov_Mikhail_Al...
# 157
# Descargando partidas de scarabee43...
# 158
# Descargando partidas de chenxiaoyuer...
# 159
# Descargando partidas de Swiss_Fighter...
# 160
# Descargando partidas de dostis...
# 161
# Descargando partidas de Reader777...
# 162
# Descargando partidas de Robert_Chessmood...
# 163
# Descargando partidas de MarkusRagger...
# 164
# Descargando partidas de liczner...
# 165
# Descargando partidas de spectralsoul...
# 166
# Descargando partidas de DrawDenied-Twitch...
# 167
# Descargando partidas de gmmoranda...
# 168
# Descargando partidas de HVillagra...
# 169
# Descargando partidas de fireheart92...
# 170
# Descargando partidas de MightyGMpretender...
# 171
# Descargando partidas de SeanWinshand...
# 172
# Descargando partidas de yavrukurt40...
# 173
# Descargando partidas de Baag4Life...
# 174
# Descargando partidas de temus_galaktionov...
# 175
# Descargando partidas de StasSB...
# 176
# Descargando partidas de SantoBlue...
# 177
# Descargando partidas de DavidGavrilescu18...
# 178
# Descargando partidas de Jagadeesh_Siddharth...
# 179
# Descargando partidas de JaloliddinIlkhomi...
# 180
# Descargando partidas de Murad_Ibrahimli...
# 181
# Descargando partidas de Arfan48...
# 182
# Descargando partidas de Adham_Fawzy...
# 183
# Descargando partidas de luckyswitchback...
# 184
# Descargando partidas de Kopylov_Alex...
# 185
# Descargando partidas de KhalilMousavi98...
# 186
# Descargando partidas de Som2310...
# 187
# Descargando partidas de FormerProdigy...
# 188
# Descargando partidas de Mudinoss...
# 189
# Descargando partidas de vas04hou...
# 190
# Descargando partidas de sergiochess83...
# 191
# Descargando partidas de howitzer14...
# 192
# Descargando partidas de Valentin_Baidetskyi...
# 193
# Descargando partidas de TrahtarBelarus...
# 194
# Descargando partidas de Talibovv06...
# 195
# Descargando partidas de rezamahdavi2008...
# 196
# Descargando partidas de Nakachuk...
# 197
# Descargando partidas de AlexKhripachenko...
# 198
# Descargando partidas de jcibarra...
# 199
# Descargando partidas de QuesadaLuisE...
# 200
# Descargando partidas de Marcan2b...
# 201
# Descargando partidas de Shankland...
# 202
# Descargando partidas de DrVelja...
# 203
# Descargando partidas de Anton_Demchenko...
# 204
# Descargando partidas de monomita...
# 205
# Descargando partidas de tptagain...
# 206
# Descargando partidas de Hatsummei...
# 207
# Descargando partidas de Keranke...
# 208
# Descargando partidas de g3god...
# 209
# Descargando partidas de AsadliVugar...
# 210
# Descargando partidas de Durarbayli...
# 211
# Descargando partidas de daro94...
# 212
# Descargando partidas de penguingm1...
# 213
# Descargando partidas de tigrangharamian...
# 214
# Descargando partidas de h4parah5...
# 215
# Descargando partidas de aa175...
# 216
# Descargando partidas de BlueWizzard...
# 217
# Descargando partidas de kuli4ik...
# 218
# Descargando partidas de Mighty_Gladius16...
# 219
# Descargando partidas de AlmasRakhmatullaev...
# 220
# Descargando partidas de hakanazeri2...
# 221
# Descargando partidas de Dolphin_2010...
# 222
# Descargando partidas de Kosak12...
# 223
# Descargando partidas de vugarrasulov...
# 224
# Descargando partidas de Binary010...
# 225
# Descargando partidas de chesterreyes...
# 226
# Descargando partidas de Elsa167...
# 227
# Descargando partidas de FGHSMN...
# 228
# Descargando partidas de OhanyanEminChess...
# 229
# Descargando partidas de Sardaukar-2...
# 230
# Descargando partidas de ilqar_74...
# 231
# Descargando partidas de RobertoJBM...
# 232
# Descargando partidas de BardArtem...
# 233
# Descargando partidas de MolecularChemist...
# 234
# Descargando partidas de xamax2000...
# 235
# Descargando partidas de Mikhail_Bryakin...
# 236
# Descargando partidas de MoonlessMay05...
# 237
# Descargando partidas de MatthewG-p4p...
# 238
# Descargando partidas de onyshchuk_v...
# 239
# Descargando partidas de gmcorrales...
# 240
# Descargando partidas de Erebuni_is_back...
# 241
# Descargando partidas de rasmussvane...
# 242
# Descargando partidas de chito89...
# 243
# Descargando partidas de eljanov...
# 244
# Descargando partidas de qsjtgx...
# 245
# Descargando partidas de demon64fields...
# 246
# Descargando partidas de platy3...
# 247
# Descargando partidas de AhmadzadaA...
# 248
# Descargando partidas de SuperPower2011...
# 249
# Descargando partidas de severomorskij...
# 250
# C:\Users\enriq\AppData\Local\Temp\ipykernel_5840\1359876324.py:28: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return pd.concat(all_games, ignore_index=True)

# %%
games = games_df.drop_duplicates()
games = games[games["time_class"] == "blitz"]
games = games[games["rules"] == "chess"]
games = games.reset_index(drop=True)
games["score_white"] = games["white_result"].apply(lambda r: map_result("white", r))
games["score_black"] = games["black_result"].apply(lambda r: map_result("black", r))
output_path = os.path.join(output_dir, "chess_games.csv")
games.to_csv(output_path, index=False, encoding="utf-8")

# %%
games.head()
# Out:
#                                             url  \
# 0  https://www.chess.com/game/live/151138695137
# 1  https://www.chess.com/game/live/151139296381
# 2  https://www.chess.com/game/live/151140489263
# 3  https://www.chess.com/game/live/151141090603
# 4  https://www.chess.com/game/live/151141697249
#
#                                                  pgn time_control time_class  \
# 0  [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...          300      blitz
# 1  [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...          300      blitz
# 2  [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...          300      blitz
# 3  [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...          300      blitz
# 4  [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...          300      blitz
#
#    accuracies_white  accuracies_black       white_username  white_rating  \
# 0             86.76             92.54  yesilikeorangejuice          2645
# 1             94.14             87.00               Hikaru          3401
# 2             88.51             88.33           RobertoJBM          2948
# 3             92.03             80.57             Artemiki          2720
# 4             95.00             86.54               Hikaru          3378
#
#   white_result black_username  black_rating black_result  eco  \
# 0     resigned         Hikaru          3400          win  B06
# 1          win  Aygehovit1992          2820     resigned  A48
# 2   repetition         Hikaru          3394   repetition  A04
# 3          win         Hikaru          3378     resigned  B06
# 4          win   soul_mortall          2555     resigned  A01
#
#                                   eco_name  rules  score_white  score_black
# 0                           Modern Defense  chess          0.0          0.0
# 1                      East Indian Defense  chess          1.0          1.0
# 2  Colle System: Rhamphorhynchus Variation  chess          0.5          0.5
# 3                           Modern Defense  chess          1.0          1.0
# 4                      Nimzo-Larsen Attack  chess          1.0          1.0

# %%
players = pd.concat([
    games[["white_username", "white_rating", "score_white"]]
        .rename(columns={"white_username": "player",
                         "white_rating": "rating",
                         "score_white": "score"}),
    games[["black_username", "black_rating", "score_black"]]
        .rename(columns={"black_username": "player",
                         "black_rating": "rating",
                         "score_black": "score"})
])

stats = players.groupby("player").agg(
    games_played=("score", "count"),
    avg_score=("score", "mean"),
    wins=("score", lambda x: (x==1).sum()),
    draws=("score", lambda x: (x==0.5).sum()),
    losses=("score", lambda x: (x==0).sum()),
    avg_rating=("rating", "mean")
).sort_values("games_played", ascending=False)

stats = stats[(stats["games_played"] > 20) & (stats.index.isin(usernames))]

# %%
stats
# Out:
#                      games_played  avg_score  wins  draws  losses   avg_rating
# player
# DanielNaroditsky             2819   0.520752  1328    280    1211  3069.789287
# Twitch_ElhamBlitz05          1836   0.550381   902    217     717  3042.900871
# bancsoo                      1810   0.522099   838    214     758  3049.549171
# ChessMaster2011_1            1411   0.521616   654    164     593  2871.537916
# Yaacovn                      1325   0.524151   619    151     555  2948.098113
# ...                           ...        ...   ...    ...     ...          ...
# ChessFighter_2011              25   0.520000    13      0      12  3045.120000
# KNVB                           23   0.695652    16      0       7  3023.000000
# GukeshDommaraju                22   0.590909    13      0       9  3049.409091
# ChessLover0108                 22   0.477273     9      3      10  3081.090909
# Denis_Makhnyov                 21   0.619048    11      4       6  3021.428571
#
# [216 rows x 6 columns]

# %%
df.head()
# Out:
#    rank       username title        country  rating  games_played   wins  \
# 0     1         Hikaru    GM  United States    3395         43183  33786
# 1     2  MagnusCarlsen    GM         Norway    3367          5591   4040
# 2     3   Firouzja2003    GM         France    3268         14303   7959
# 3     4      LyonBeast    GM         France    3249          3345   2092
# 4     5      lachesisQ    GM         Russia    3232          7493   4312
#
#    losses  draws
# 0    5291   4106
# 1     867    684
# 2    4568   1776
# 3     746    507
# 4    2169   1012

# %%
def build_players_table(games, leaderboard):
    players = pd.concat([
        games[["white_username", "white_rating", "score_white"]]
            .rename(columns={"white_username": "player",
                             "white_rating": "rating",
                             "score_white": "score"}),
        games[["black_username", "black_rating", "score_black"]]
            .rename(columns={"black_username": "player",
                             "black_rating": "rating",
                             "score_black": "score"})
    ])

    stats = players.groupby("player").agg(
        games_played=("score", "count"),
        avg_score=("score", "mean"),
        wins=("score", lambda x: (x == 1).sum()),
        draws=("score", lambda x: (x == 0.5).sum()),
        losses=("score", lambda x: (x == 0).sum()),
        avg_rating=("rating", "mean")
    ).reset_index()

    leaderboard_players = leaderboard[["username", "rank", "title", "country"]]

    players_table = stats.merge(
        leaderboard_players,
        left_on="player", right_on="username", how="inner"
    ).drop(columns="username")

    return players_table

# %%
jugadores = build_players_table(games,df)

# %%
jugadores[jugadores["title"].isna()]
# Out:
#                player  games_played  avg_score  wins  draws  losses  \
# 115  Mighty_Gladius16            51   0.509804    22      8      21
# 184      chesterreyes             2   0.500000     1      0       1
# 222      ricky8632200            13   0.269231     2      3       8
#
#       avg_rating  rank title      country
# 115  2946.607843   220  None        India
# 184  2978.500000   229  None  Philippines
# 222  3014.461538   125  None        China

# %%
import pandas as pd
import os

output_dir = "../data"

games = pd.read_csv(os.path.join(output_dir, "games.csv"))
leaders = pd.read_csv(os.path.join(output_dir, "chess_ratings.csv"))

print(games.shape, leaders.shape)
games.head()
# Out:
# (53668, 16) (250, 9)
#                                             url  \
# 0  https://www.chess.com/game/live/151138695137
# 1  https://www.chess.com/game/live/151139296381
# 2  https://www.chess.com/game/live/151140489263
# 3  https://www.chess.com/game/live/151141090603
# 4  https://www.chess.com/game/live/151141697249
#
#                                                  pgn time_control time_class  \
# 0  [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...          300      blitz
# 1  [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...          300      blitz
# 2  [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...          300      blitz
# 3  [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...          300      blitz
# 4  [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...          300      blitz
#
#    accuracies_white  accuracies_black       white_username  white_rating  \
# 0             86.76             92.54  yesilikeorangejuice          2645
# 1             94.09             86.99               Hikaru          3401
# 2             88.51             88.33           RobertoJBM          2948
# 3             92.03             80.57             Artemiki          2720
# 4             95.00             86.54               Hikaru          3378
#
#   white_result black_username  black_rating black_result  \
# 0     resigned         Hikaru          3400          win
# 1          win  Aygehovit1992          2820     resigned
# 2   repetition         Hikaru          3394   repetition
# 3          win         Hikaru          3378     resigned
# 4          win   soul_mortall          2555     resigned
#
#                                                  eco  rules  score_white  \
# 0  https://www.chess.com/openings/Modern-Defense-...  chess          0.0
# 1  https://www.chess.com/openings/Indian-Game-Kni...  chess          1.0
# 2  https://www.chess.com/openings/Reti-Opening-Du...  chess          0.5
# 3  https://www.chess.com/openings/Modern-Defense-...  chess          1.0
# 4  https://www.chess.com/openings/Nimzowitsch-Lar...  chess          1.0
#
#    score_black
# 0          0.0
# 1          1.0
# 2          0.5
# 3          1.0
# 4          1.0

# %%
games["eco"][0].split("/")[-1]
# Out:
# 'Modern-Defense-with-1-e4...3.Nf3-c6-4.Bd3-d6'

# %%
games["eco"].isna().sum()
# Out:
# 0

# %%
def get_player_info(username: str):
    """
    Devuelve nombre y avatar de un jugador de Chess.com.
    """
    url = f"https://api.chess.com/pub/player/{username}"
    headers = {"User-Agent": "Mozilla/5.0"}
    r = requests.get(url, headers=headers)
    time.sleep(0.5)  # pausa para no saturar la API
    
    if r.status_code == 200:
        data = r.json()
        return {
            "name": data.get("name"),
            "avatar": data.get("avatar")
        }
    return {"name": None, "avatar": None}

# %%
def add_flag_url(df):
    df["country_code"] = df["country"].str.split("/").str[-1].str.lower()
    df["flag_url"] = "https://flagcdn.com/h20/" + df["country_code"] + ".png"
    return df

# %%
url = f"https://api.chess.com/pub/player/xamax2000"
headers = {"User-Agent": "Mozilla/5.0"}
r = requests.get(url, headers=headers)
r.json()
# Out:
# {'player_id': 26608680,
#  '@id': 'https://api.chess.com/pub/player/xamax2000',
#  'url': 'https://www.chess.com/member/xamax2000',
#  'name': 'Max Warmerdam',
#  'username': 'xamax2000',
#  'title': 'GM',
#  'followers': 312,
#  'country': 'https://api.chess.com/pub/country/NL',
#  'location': 'Tegelen',
#  'last_online': 1754734203,
#  'joined': 1455002600,
#  'status': 'premium',
#  'is_streamer': False,
#  'verified': False,
#  'league': 'Legend',
#  'streaming_platforms': []}

# %%
leaders = pd.read_csv(os.path.join(output_dir, "chess_ratings.csv"))
leaders
# Out:
#      rank        username title        country  rating  games_played   wins  \
# 0       1          Hikaru    GM  United States    3395         43183  33786
# 1       2   MagnusCarlsen    GM         Norway    3367          5591   4040
# 2       3    Firouzja2003    GM         France    3268         14303   7959
# 3       4       LyonBeast    GM         France    3249          3345   2092
# 4       5       lachesisQ    GM         Russia    3232          7493   4312
# ..    ...             ...   ...            ...     ...           ...    ...
# 245   246          qsjtgx    IM          China    2962          8125   3812
# 246   247          platy3    GM          Spain    2962          4245   2376
# 247   248     SPEEDSKATER    GM  United States    2962          8107   4490
# 248   249      AhmadzadaA    GM     Azerbaijan    2961          2055    979
# 249   250  SuperPower2011    IM        Romania    2961           803    418
#
#      losses  draws
# 0      5291   4106
# 1       867    684
# 2      4568   1776
# 3       746    507
# 4      2169   1012
# ..      ...    ...
# 245    3593    720
# 246    1337    532
# 247    2670    947
# 248     781    295
# 249     331     54
#
# [250 rows x 9 columns]

# %%
players = pd.read_csv(os.path.join(output_dir, "players_stats.csv"))

# %%
# --- construir stats recientes desde games ---
players = pd.concat([
    games[["white_username", "white_rating", "score_white"]]
        .rename(columns={"white_username": "player",
                         "white_rating": "rating",
                         "score_white": "score"}),
    games[["black_username", "black_rating", "score_black"]]
        .rename(columns={"black_username": "player",
                         "black_rating": "rating",
                         "score_black": "score"})
])

# %%
stats = players.groupby("player").agg(
    games_played=("score", "count"),
    avg_score=("score", "mean"),
    wins=("score", lambda x: (x == 1).sum()),
    draws=("score", lambda x: (x == 0.5).sum()),
    losses=("score", lambda x: (x == 0).sum())
).reset_index()

# %%
# --- merge con leaderboard (stats globales) ---
players_table = stats.merge(
    leaders[["username", "rank", "title", "country", "rating",
             "games_played", "wins", "losses", "draws"]],
    left_on="player", right_on="username", how="inner"
).drop(columns="username")

# %%
# --- renombrar columnas ---
players_table = players_table.rename(columns={
    "games_played_x": "games_played_recent",
    "wins_x": "wins_recent",
    "draws_x": "draws_recent",
    "losses_x": "losses_recent",
    "games_played_y": "games_played_total",
    "wins_y": "wins_total",
    "draws_y": "draws_total",
    "losses_y": "losses_total"
    })

# %%
players_table.head(2)
# Out:
#      player  games_played_recent  avg_score  wins_recent  draws_recent  \
# 0  0gZPanda                  120   0.620833           66            17
# 1    A-Adly                   85   0.635294           50             8
#
#    losses_recent  rank title        country  rating  games_played_total  \
# 0             37    12    IM  United States    3179                5471
# 1             27   128    GM          Egypt    3026                1151
#
#    wins_total  losses_total  draws_total
# 0        2926          1993          552
# 1         655           401           95

# %%
# --- añadir nombre y avatar ---
players_table[["name", "avatar"]] = players_table["player"].apply(
    lambda u: pd.Series(get_player_info(u))
)

# --- ordenar columnas ---
players_table = players_table[
    ["player", "name", "avatar", "rank", "title", "country", "rating",
     "games_played_recent", "wins_recent", "draws_recent", "losses_recent",
     "games_played_total", "wins_total", "draws_total", "losses_total",
     "avg_score"]
]

# %%
players_table = add_flag_url(players_table)

# %%
output_path = os.path.join(output_dir, "players_stats.csv")
players_table.to_csv(output_path, index=False, encoding="utf-8")

# %%
url = "https://api.chess.com/pub/tournament/titled-tuesday-blitz-september-09-2025-5905665"
r = requests.get(url, headers=headers)
t = r.json()

# %%
rounds = requests.get("https://api.chess.com/pub/tournament/titled-tuesday-blitz-september-09-2025-5905665/11/1",headers = headers)

# %%
rounds.json()
# Out:
# {'code': 0,
#  'message': 'Tournament "titled-tuesday-blitz-september-09-2025-5905665" doesn\'t have group "1" in round "10".'}

# %%
players_table = pd.read_csv(os.path.join(output_dir, "players_stats.csv"))

# %%
DATA_DIR = "../data"
games = pd.read_csv(os.path.join(DATA_DIR, "chess_games.csv"))

# %%
games
# Out:
#                                                 url  \
# 0      https://www.chess.com/game/live/151138695137
# 1      https://www.chess.com/game/live/151139296381
# 2      https://www.chess.com/game/live/151140489263
# 3      https://www.chess.com/game/live/151141090603
# 4      https://www.chess.com/game/live/151141697249
# ...                                             ...
# 53305  https://www.chess.com/game/live/141789898502
# 53306  https://www.chess.com/game/live/141790118426
# 53307  https://www.chess.com/game/live/141790279374
# 53308  https://www.chess.com/game/live/141790450442
# 53309  https://www.chess.com/game/live/141790662246
#
#                                                      pgn time_control  \
# 0      [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...          300
# 1      [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...          300
# 2      [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...          300
# 3      [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...          300
# 4      [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...          300
# ...                                                  ...          ...
# 53305  [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...          180
# 53306  [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...          180
# 53307  [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...          180
# 53308  [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...          180
# 53309  [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...          180
#
#       time_class  accuracies_white  accuracies_black        white_username  \
# 0          blitz             86.76             92.54   yesilikeorangejuice
# 1          blitz             94.14             87.00                Hikaru
# 2          blitz             88.51             88.33            RobertoJBM
# 3          blitz             92.03             80.57              Artemiki
# 4          blitz             95.00             86.54                Hikaru
# ...          ...               ...               ...                   ...
# 53305      blitz             89.97             84.27        SuperPower2011
# 53306      blitz             75.08             84.34  ScacchiParlanoDaSoli
# 53307      blitz             91.04             84.69        SuperPower2011
# 53308      blitz             80.10             85.62  ScacchiParlanoDaSoli
# 53309      blitz             92.18             82.20        SuperPower2011
#
#        white_rating white_result        black_username  black_rating  \
# 0              2645     resigned                Hikaru          3400
# 1              3401          win         Aygehovit1992          2820
# 2              2948   repetition                Hikaru          3394
# 3              2720          win                Hikaru          3378
# 4              3378          win          soul_mortall          2555
# ...             ...          ...                   ...           ...
# 53305          2949          win  ScacchiParlanoDaSoli          2722
# 53306          2719     resigned        SuperPower2011          2952
# 53307          2955          win  ScacchiParlanoDaSoli          2716
# 53308          2713      timeout        SuperPower2011          2958
# 53309          2961          win  ScacchiParlanoDaSoli          2710
#
#       black_result  eco                                           eco_name  \
# 0              win  B06                                     Modern Defense
# 1         resigned  A48                                East Indian Defense
# 2       repetition  A04            Colle System: Rhamphorhynchus Variation
# 3         resigned  B06                                     Modern Defense
# 4         resigned  A01                                Nimzo-Larsen Attack
# ...            ...  ...                                                ...
# 53305   checkmated  E91            King's Indian Defense: Kazakh Variation
# 53306          win  B15                                  Caro-Kann Defense
# 53307     resigned  B76  Sicilian Defense: Dragon Variation, Yugoslav A...
# 53308          win  B50                                   Sicilian Defense
# 53309   checkmated  B45           Sicilian Defense: Four Knights Variation
#
#        rules  score_white  score_black
# 0      chess          0.0          0.0
# 1      chess          1.0          1.0
# 2      chess          0.5          0.5
# 3      chess          1.0          1.0
# 4      chess          1.0          1.0
# ...      ...          ...          ...
# 53305  chess          1.0          1.0
# 53306  chess          0.0          0.0
# 53307  chess          1.0          1.0
# 53308  chess          0.0          0.0
# 53309  chess          1.0          1.0
#
# [53310 rows x 17 columns]

# %%
url = f"https://api.chess.com/pub/player/Hikaru/games/2025/09"
headers = {"User-Agent": "Mozilla/5.0"}
    
r = requests.get(url, headers=headers)

# %%
url = "https://api.chess.com/pub/player/Hikaru/tournaments"
headers = {"User-Agent": "Mozilla/5.0"}
    
r = requests.get(url, headers=headers)

# %%
players
# Out:
# [{'rank': 201,
#   'username': 'Marcan2b',
#   'title': 'GM',
#   'country': 'France',
#   'rating': 2996,
#   'games_played': 12222,
#   'wins': 6475,
#   'losses': 4924,
#   'draws': 823},
#  {'rank': 202,
#   'username': 'Shankland',
#   'title': 'GM',
#   'country': 'United States',
#   'rating': 2996,
#   'games_played': 4736,
#   'wins': 2547,
#   'losses': 1494,
#   'draws': 695},
#  {'rank': 203,
#   'username': 'DrVelja',
#   'title': 'GM',
#   'country': 'Serbia',
#   'rating': 2994,
#   'games_played': 5206,
#   'wins': 2833,
#   'losses': 1912,
#   'draws': 461},
#  {'rank': 204,
#   'username': 'Anton_Demchenko',
#   'title': 'GM',
#   'country': 'Slovenia',
#   'rating': 2994,
#   'games_played': 15035,
#   'wins': 7720,
#   'losses': 5596,
#   'draws': 1719},
#  {'rank': 205,
#   'username': 'monomita',
#   'title': 'IM',
#   'country': 'India',
#   'rating': 2993,
#   'games_played': 2325,
#   'wins': 1105,
#   'losses': 939,
#   'draws': 281},
#  {'rank': 206,
#   'username': 'tptagain',
#   'title': 'GM',
#   'country': 'Spain',
#   'rating': 2991,
#   'games_played': 8526,
#   'wins': 5005,
#   'losses': 2551,
#   'draws': 970},
#  {'rank': 207,
#   'username': 'Hatsummei',
#   'title': 'IM',
#   'country': 'Russia',
#   'rating': 2991,
#   'games_played': 3628,
#   'wins': 1764,
#   'losses': 1592,
#   'draws': 272},
#  {'rank': 208,
#   'username': 'Keranke',
#   'title': 'IM',
#   'country': 'Russia',
#   'rating': 2991,
#   'games_played': 15940,
#   'wins': 7775,
#   'losses': 6859,
#   'draws': 1306},
#  {'rank': 209,
#   'username': 'g3god',
#   'title': 'GM',
#   'country': 'India',
#   'rating': 2990,
#   'games_played': 6299,
#   'wins': 2815,
#   'losses': 2663,
#   'draws': 821},
#  {'rank': 210,
#   'username': 'AsadliVugar',
#   'title': 'GM',
#   'country': 'Azerbaijan',
#   'rating': 2990,
#   'games_played': 6761,
#   'wins': 3659,
#   'losses': 2383,
#   'draws': 719},
#  {'rank': 211,
#   'username': 'Durarbayli',
#   'title': 'GM',
#   'country': 'Azerbaijan',
#   'rating': 2990,
#   'games_played': 7659,
#   'wins': 4137,
#   'losses': 2767,
#   'draws': 755},
#  {'rank': 212,
#   'username': 'daro94',
#   'title': 'GM',
#   'country': 'United States',
#   'rating': 2989,
#   'games_played': 7126,
#   'wins': 3444,
#   'losses': 2752,
#   'draws': 930},
#  {'rank': 213,
#   'username': 'penguingm1',
#   'title': 'GM',
#   'country': 'United States',
#   'rating': 2988,
#   'games_played': 9257,
#   'wins': 5696,
#   'losses': 2922,
#   'draws': 639},
#  {'rank': 214,
#   'username': 'tigrangharamian',
#   'title': 'GM',
#   'country': 'France',
#   'rating': 2988,
#   'games_played': 1163,
#   'wins': 637,
#   'losses': 376,
#   'draws': 150},
#  {'rank': 215,
#   'username': 'h4parah5',
#   'title': 'GM',
#   'country': 'Spain',
#   'rating': 2988,
#   'games_played': 1282,
#   'wins': 766,
#   'losses': 363,
#   'draws': 153},
#  {'rank': 216,
#   'username': 'aa175',
#   'title': 'IM',
#   'country': 'Canada',
#   'rating': 2987,
#   'games_played': 12389,
#   'wins': 6034,
#   'losses': 5399,
#   'draws': 956},
#  {'rank': 217,
#   'username': 'BlueWizzard',
#   'title': 'GM',
#   'country': 'United States',
#   'rating': 2985,
#   'games_played': 10215,
#   'wins': 6455,
#   'losses': 3050,
#   'draws': 710},
#  {'rank': 218,
#   'username': 'kuli4ik',
#   'title': 'GM',
#   'country': 'Russia',
#   'rating': 2980,
#   'games_played': 6091,
#   'wins': 2778,
#   'losses': 2395,
#   'draws': 918},
#  {'rank': 219,
#   'username': 'Mighty_Gladius16',
#   'title': None,
#   'country': 'India',
#   'rating': 2980,
#   'games_played': 1754,
#   'wins': 869,
#   'losses': 653,
#   'draws': 232},
#  {'rank': 220,
#   'username': 'AlmasRakhmatullaev',
#   'title': 'IM',
#   'country': 'Uzbekistan',
#   'rating': 2979,
#   'games_played': 2499,
#   'wins': 1257,
#   'losses': 1013,
#   'draws': 229},
#  {'rank': 221,
#   'username': 'hakanazeri2',
#   'title': 'IM',
#   'country': 'Nauru',
#   'rating': 2979,
#   'games_played': 9932,
#   'wins': 4447,
#   'losses': 4547,
#   'draws': 938},
#  {'rank': 222,
#   'username': 'Dolphin_2010',
#   'title': 'FM',
#   'country': 'Russia',
#   'rating': 2978,
#   'games_played': 923,
#   'wins': 567,
#   'losses': 295,
#   'draws': 61},
#  {'rank': 223,
#   'username': 'Kosak12',
#   'title': 'GM',
#   'country': 'Poland',
#   'rating': 2978,
#   'games_played': 3196,
#   'wins': 1936,
#   'losses': 998,
#   'draws': 262},
#  {'rank': 224,
#   'username': 'vugarrasulov',
#   'title': 'GM',
#   'country': 'Azerbaijan',
#   'rating': 2977,
#   'games_played': 11817,
#   'wins': 7428,
#   'losses': 3095,
#   'draws': 1294},
#  {'rank': 225,
#   'username': 'Binary010',
#   'title': 'GM',
#   'country': 'United States',
#   'rating': 2977,
#   'games_played': 13416,
#   'wins': 6158,
#   'losses': 5445,
#   'draws': 1813},
#  {'rank': 226,
#   'username': 'chesterreyes',
#   'title': None,
#   'country': 'Philippines',
#   'rating': 2976,
#   'games_played': 1695,
#   'wins': 963,
#   'losses': 609,
#   'draws': 123},
#  {'rank': 227,
#   'username': 'Elsa167',
#   'title': 'GM',
#   'country': 'Croatia',
#   'rating': 2976,
#   'games_played': 4204,
#   'wins': 2116,
#   'losses': 1588,
#   'draws': 500},
#  {'rank': 228,
#   'username': 'FGHSMN',
#   'title': 'GM',
#   'country': 'India',
#   'rating': 2976,
#   'games_played': 10803,
#   'wins': 5851,
#   'losses': 4107,
#   'draws': 845},
#  {'rank': 229,
#   'username': 'OhanyanEminChess',
#   'title': 'GM',
#   'country': 'Armenia',
#   'rating': 2975,
#   'games_played': 8706,
#   'wins': 4219,
#   'losses': 3725,
#   'draws': 762},
#  {'rank': 230,
#   'username': 'Sardaukar-2',
#   'title': 'IM',
#   'country': 'Ukraine',
#   'rating': 2975,
#   'games_played': 1397,
#   'wins': 801,
#   'losses': 468,
#   'draws': 128},
#  {'rank': 231,
#   'username': 'ilqar_74',
#   'title': 'FM',
#   'country': 'Azerbaijan',
#   'rating': 2975,
#   'games_played': 4792,
#   'wins': 2585,
#   'losses': 1542,
#   'draws': 665},
#  {'rank': 232,
#   'username': 'RobertoJBM',
#   'title': 'IM',
#   'country': 'Brazil',
#   'rating': 2975,
#   'games_played': 20343,
#   'wins': 10130,
#   'losses': 7354,
#   'draws': 2859},
#  {'rank': 233,
#   'username': 'BardArtem',
#   'title': 'FM',
#   'country': 'International',
#   'rating': 2972,
#   'games_played': 7324,
#   'wins': 3706,
#   'losses': 2855,
#   'draws': 763},
#  {'rank': 234,
#   'username': 'MolecularChemist',
#   'title': 'IM',
#   'country': 'United States',
#   'rating': 2972,
#   'games_played': 6035,
#   'wins': 3166,
#   'losses': 2126,
#   'draws': 743},
#  {'rank': 235,
#   'username': 'xamax2000',
#   'title': 'GM',
#   'country': 'Netherlands',
#   'rating': 2972,
#   'games_played': 6908,
#   'wins': 3788,
#   'losses': 2344,
#   'draws': 776},
#  {'rank': 236,
#   'username': 'Mikhail_Bryakin',
#   'title': 'GM',
#   'country': 'Serbia',
#   'rating': 2967,
#   'games_played': 8965,
#   'wins': 4628,
#   'losses': 3107,
#   'draws': 1230},
#  {'rank': 237,
#   'username': 'MoonlessMay05',
#   'title': 'GM',
#   'country': 'Israel',
#   'rating': 2967,
#   'games_played': 3959,
#   'wins': 2048,
#   'losses': 1507,
#   'draws': 404},
#  {'rank': 238,
#   'username': 'MatthewG-p4p',
#   'title': 'IM',
#   'country': 'Russia',
#   'rating': 2966,
#   'games_played': 6489,
#   'wins': 3771,
#   'losses': 2185,
#   'draws': 533},
#  {'rank': 239,
#   'username': 'onyshchuk_v',
#   'title': 'GM',
#   'country': 'Ukraine',
#   'rating': 2966,
#   'games_played': 1055,
#   'wins': 680,
#   'losses': 259,
#   'draws': 116},
#  {'rank': 240,
#   'username': 'gmcorrales',
#   'title': 'GM',
#   'country': 'United States',
#   'rating': 2966,
#   'games_played': 24034,
#   'wins': 11038,
#   'losses': 9752,
#   'draws': 3244},
#  {'rank': 241,
#   'username': 'Erebuni_is_back',
#   'title': 'IM',
#   'country': 'Armenia',
#   'rating': 2965,
#   'games_played': 1015,
#   'wins': 579,
#   'losses': 322,
#   'draws': 114},
#  {'rank': 242,
#   'username': 'rasmussvane',
#   'title': 'GM',
#   'country': 'Germany',
#   'rating': 2965,
#   'games_played': 8718,
#   'wins': 5471,
#   'losses': 2159,
#   'draws': 1088},
#  {'rank': 243,
#   'username': 'chito89',
#   'title': 'GM',
#   'country': 'Paraguay',
#   'rating': 2965,
#   'games_played': 9166,
#   'wins': 4931,
#   'losses': 3409,
#   'draws': 826},
#  {'rank': 244,
#   'username': 'eljanov',
#   'title': 'GM',
#   'country': 'Ukraine',
#   'rating': 2965,
#   'games_played': 13516,
#   'wins': 5867,
#   'losses': 5679,
#   'draws': 1970},
#  {'rank': 245,
#   'username': 'qsjtgx',
#   'title': 'IM',
#   'country': 'China',
#   'rating': 2962,
#   'games_played': 8125,
#   'wins': 3812,
#   'losses': 3593,
#   'draws': 720},
#  {'rank': 246,
#   'username': 'demon64fields',
#   'title': 'IM',
#   'country': 'Russia',
#   'rating': 2962,
#   'games_played': 3079,
#   'wins': 1348,
#   'losses': 1368,
#   'draws': 363},
#  {'rank': 247,
#   'username': 'platy3',
#   'title': 'GM',
#   'country': 'Spain',
#   'rating': 2962,
#   'games_played': 4245,
#   'wins': 2376,
#   'losses': 1337,
#   'draws': 532},
#  {'rank': 248,
#   'username': 'AhmadzadaA',
#   'title': 'GM',
#   'country': 'Azerbaijan',
#   'rating': 2961,
#   'games_played': 2055,
#   'wins': 979,
#   'losses': 781,
#   'draws': 295},
#  {'rank': 249,
#   'username': 'SuperPower2011',
#   'title': 'IM',
#   'country': 'Romania',
#   'rating': 2961,
#   'games_played': 803,
#   'wins': 418,
#   'losses': 331,
#   'draws': 54},
#  {'rank': 250,
#   'username': 'severomorskij',
#   'title': 'GM',
#   'country': 'Ukraine',
#   'rating': 2961,
#   'games_played': 1557,
#   'wins': 825,
#   'losses': 548,
#   'draws': 184}]
